# %%
import pandas as pd

# %%
df1 = pd.read_csv('input/variant-names.csv')
df2 = pd.read_csv('input/dll-works-and-authors.csv')

# %%
# Filter out the unneeded columns
names_works = df2[['Title', 'DLL Identifier (Work)', 'Author Name Latin', 'DLL Identifier (Author)']]

# %%
# Reduce the set to rows with a value in "Author Name Latin"
la_names_works = names_works[~names_works['Author Name Latin'].isna()].reset_index()

# %%
# Compare the number of records in both
print(f"Original number of records: {len(names_works)}")
print(f"Number of records with Latin author names:  {len(la_names_works)}")
# Out:
# Original number of records: 5279
# Number of records with Latin author names:  4753

# %%
# import Spacy and LatinCy model
import spacy

# %%
# Load the large Latin model from LatinCy
nlp = spacy.load('la_core_web_lg')

# %%
# Inspect the first five rows of the dataframe
la_names_works.head()
# Out:
#    index                                    Title DLL Identifier (Work)  \
# 0      0  De signis et symptomatibus aegritudinum                W10655
# 1      2                                     Alda                W10653
# 2      3                     De Viris Illustribus                W10652
# 3      4                           De Philosophis                W10651
# 4      5                 Epigrammata super exilio                W10650
#
#              Author Name Latin DLL Identifier (Author)  \
# 0         Aegidius Corbeiensis                   A3919
# 1          Guilelmus Blasensis                   A4844
# 2  Gaius Suetonius Tranquillus                   A4799
# 3  Gaius Suetonius Tranquillus                   A4799
# 4        Lucius Annaeus Seneca                   A4655
#
#                      Title_Lemmatized Title Label Author Label
# 0  de signum et symptomatis aegritudo       TITLE       PERSON
# 1                                alda       TITLE       PERSON
# 2                    de uir illustris       TITLE       PERSON
# 3                      de philosophus       TITLE       PERSON
# 4             epigramma super exilium       TITLE       PERSON

# %%
# Add columns with NER labels for titles and people
la_names_works['Title Label'] = "TITLE"
la_names_works['Author Label'] = "PERSON"

# %%
# Function to get lemmas from a text string
def get_lemmas(text):
    # Apply the model to the text
    doc = nlp(text)
    # Normalize the tokens in the text
    normals = [item.norm_ for item in doc]
    normalized = (' ').join(normals)
    # Apply the model to the new text
    normaldoc = nlp(normalized)
    # Lemmatize the text
    lemmas = [token.lemma_ for token in normaldoc]
    return ' '.join(lemmas)  # Return lemmas as a single string

# %%
# Apply the function to the 'Title' column (or any other column)
la_names_works['Title_Lemmatized'] = la_names_works['Title'].apply(get_lemmas)

# %%
la_names_works.head()
# Out:
#    index                                    Title DLL Identifier (Work)  \
# 0      0  De signis et symptomatibus aegritudinum                W10655
# 1      2                                     Alda                W10653
# 2      3                     De Viris Illustribus                W10652
# 3      4                           De Philosophis                W10651
# 4      5                 Epigrammata super exilio                W10650
#
#              Author Name Latin DLL Identifier (Author)  \
# 0         Aegidius Corbeiensis                   A3919
# 1          Guilelmus Blasensis                   A4844
# 2  Gaius Suetonius Tranquillus                   A4799
# 3  Gaius Suetonius Tranquillus                   A4799
# 4        Lucius Annaeus Seneca                   A4655
#
#                      Title_Lemmatized Title Label Author Label
# 0  de signum et symptomatis aegritudo       TITLE       PERSON
# 1                                alda       TITLE       PERSON
# 2                    de uir illustris       TITLE       PERSON
# 3                      de philosophus       TITLE       PERSON
# 4             epigramma super exilium       TITLE       PERSON

# %%
# Lemmatize the author names
la_names_works['Author_Lemmatized'] = la_names_works['Author Name Latin'].apply(get_lemmas)

# %%
la_names_works.head()
# Out:
#    index                                    Title DLL Identifier (Work)  \
# 0      0  De signis et symptomatibus aegritudinum                W10655
# 1      2                                     Alda                W10653
# 2      3                     De Viris Illustribus                W10652
# 3      4                           De Philosophis                W10651
# 4      5                 Epigrammata super exilio                W10650
#
#              Author Name Latin DLL Identifier (Author)  \
# 0         Aegidius Corbeiensis                   A3919
# 1          Guilelmus Blasensis                   A4844
# 2  Gaius Suetonius Tranquillus                   A4799
# 3  Gaius Suetonius Tranquillus                   A4799
# 4        Lucius Annaeus Seneca                   A4655
#
#                      Title_Lemmatized Title Label Author Label  \
# 0  de signum et symptomatis aegritudo       TITLE       PERSON
# 1                                alda       TITLE       PERSON
# 2                    de uir illustris       TITLE       PERSON
# 3                      de philosophus       TITLE       PERSON
# 4             epigramma super exilium       TITLE       PERSON
#
#              Author_Lemmatized
# 0           aegide corbeiensis
# 1           guilelmus blasendo
# 2  gaius suetonius tranquillus
# 3  gaius suetonius tranquillus
# 4       lucius annaeus senecus

# %%
ner_frame = la_names_works[['Author_Lemmatized','Author Label','Title_Lemmatized','Title Label']]

# %%
from spacy.tokens import DocBin

# %%
# Initialize a blank Latin model, adjust if needed
nlp = spacy.blank("la")
doc_bin = DocBin()  # Create a DocBin for storing Doc objects

# Assuming your DataFrame is already loaded and named df
for index, row in ner_frame.iterrows():
    author = row['Author_Lemmatized']
    author_label = row['Author Label']
    title = row['Title_Lemmatized']
    title_label = row['Title Label']
    
    # Create a simple sentence or string with the author and title
    text = f"{author} {title}"
    
    # Create a SpaCy Doc object
    doc = nlp.make_doc(text)
    entities = []
    
    # Find and annotate the author
    author_start = text.find(author)
    author_end = author_start + len(author)
    
    # Only add the entity if the char_span is valid
    author_span = doc.char_span(author_start, author_end, label=author_label)
    if author_span is not None:
        entities.append(author_span)
    
    # Find and annotate the title
    title_start = text.find(title)
    title_end = title_start + len(title)
    
    # Only add the entity if the char_span is valid
    title_span = doc.char_span(title_start, title_end, label=title_label)
    if title_span is not None:
        entities.append(title_span)
    
    # Set annotations
    doc.ents = entities
    
    # Add the doc to the DocBin
    doc_bin.add(doc)

# Save the DocBin to disk
output_file = 'train_data.spacy'
doc_bin.to_disk(output_file)

print(f"Training data saved to {output_file}")
# Out:
# Training data saved to train_data.spacy

# %%
# Load the saved training data
doc_bin = DocBin().from_disk("train_data.spacy")

# Convert the DocBin to a list of Doc objects
docs = list(doc_bin.get_docs(nlp.vocab))

# Inspect the training data
for doc in docs:
    print(f"Text: {doc.text}")
    for ent in doc.ents:
        print(f" - Entity: {ent.text}, Label: {ent.label_}, Start: {ent.start_char}, End: {ent.end_char}")
    print("-" * 40)  # Separator for readability
# Out:
# Text: aegide corbeiensis de signum et symptomatis aegritudo
#  - Entity: aegide corbeiensis, Label: PERSON, Start: 0, End: 18
#  - Entity: de signum et symptomatis aegritudo, Label: TITLE, Start: 19, End: 53
# ----------------------------------------
# Text: guilelmus blasendo alda
#  - Entity: guilelmus blasendo, Label: PERSON, Start: 0, End: 18
#  - Entity: alda, Label: TITLE, Start: 19, End: 23
# ----------------------------------------
# Text: gaius suetonius tranquillus de uir illustris
#  - Entity: gaius suetonius tranquillus, Label: PERSON, Start: 0, End: 27
#  - Entity: de uir illustris, Label: TITLE, Start: 28, End: 44
# ----------------------------------------
# Text: gaius suetonius tranquillus de philosophus
#  - Entity: gaius suetonius tranquillus, Label: PERSON, Start: 0, End: 27
#  - Entity: de philosophus, Label: TITLE, Start: 28, End: 42
# ----------------------------------------
# Text: lucius annaeus senecus epigramma super exilium
#  - Entity: lucius annaeus senecus, Label: PERSON, Start: 0, End: 22
#  - Entity: epigramma super exilium, Label: TITLE, Start: 23, End: 46
# ----------------------------------------
# Text: odo cluniacendo occupatio
#  - Entity: odo cluniacendo, Label: PERSON, Start: 0, End: 15
#  - Entity: occupatio, Label: TITLE, Start: 16, End: 25
# ----------------------------------------
# Text: lucius annaeus senecus liber senecus de mos
#  - Entity: lucius annaeus senecus, Label: PERSON, Start: 0, End: 22
#  - Entity: liber senecus de mos, Label: TITLE, Start: 23, End: 43
# ----------------------------------------
# Text: marcus antonius muretus praefatio
#  - Entity: marcus antonius muretus, Label: PERSON, Start: 0, End: 23
#  - Entity: praefatio, Label: TITLE, Start: 24, End: 33
# ----------------------------------------
# Text: marcus antonius muretus oratio
#  - Entity: marcus antonius muretus, Label: PERSON, Start: 0, End: 23
#  - Entity: oratio, Label: TITLE, Start: 24, End: 30
# ----------------------------------------
# Text: lucius apuleius madaurendo psyche et cupido
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: psyche et cupido, Label: TITLE, Start: 27, End: 43
# ----------------------------------------
# Text: albanus torinus de facultas alimentum ex paulus aegienno , albanus torinus interpres
#  - Entity: albanus torinus, Label: PERSON, Start: 0, End: 15
#  - Entity: de facultas alimentum ex paulus aegienno , albanus torinus interpres, Label: TITLE, Start: 16, End: 84
# ----------------------------------------
# Text: hugo grotus delphiendo  damascenus de institutio caesar augustus
#  - Entity: hugo grotus delphiendo, Label: PERSON, Start: 0, End: 22
#  - Entity:  damascenus de institutio caesar augustus, Label: TITLE, Start: 23, End: 64
# ----------------------------------------
# Text: scipio gentilis in l.s apuleus philosophus et aduoco romanus apologia commentarius
#  - Entity: scipio gentilis, Label: PERSON, Start: 0, End: 15
#  - Entity: in l.s apuleus philosophus et aduoco romanus apologia commentarius, Label: TITLE, Start: 16, End: 82
# ----------------------------------------
# Text: baartholomaeus platinum de honesto uoluptas et ualetudo
#  - Entity: baartholomaeus platinum, Label: PERSON, Start: 0, End: 23
#  - Entity: de honesto uoluptas et ualetudo, Label: TITLE, Start: 24, End: 55
# ----------------------------------------
# Text: ambrosius mediolanendo de benedictio patriarcha
#  - Entity: ambrosius mediolanendo, Label: PERSON, Start: 0, End: 22
#  - Entity: de benedictio patriarcha, Label: TITLE, Start: 23, End: 47
# ----------------------------------------
# Text: petrus abaelardus introductio ad theologia
#  - Entity: petrus abaelardus, Label: PERSON, Start: 0, End: 17
#  - Entity: introductio ad theologia, Label: TITLE, Start: 18, End: 42
# ----------------------------------------
# Text: petrus abaelardus sermo per annus lego
#  - Entity: petrus abaelardus, Label: PERSON, Start: 0, End: 17
#  - Entity: sermo per annus lego, Label: TITLE, Start: 18, End: 38
# ----------------------------------------
# Text: petrus abaelardus magister petrus abelardus et heloisssa coniunx is epistola
#  - Entity: petrus abaelardus, Label: PERSON, Start: 0, End: 17
#  - Entity: magister petrus abelardus et heloisssa coniunx is epistola, Label: TITLE, Start: 18, End: 76
# ----------------------------------------
# Text: heloissum magister petrus abelardus et heloisssa coniunx is epistola
#  - Entity: heloissum, Label: PERSON, Start: 0, End: 9
#  - Entity: magister petrus abelardus et heloisssa coniunx is epistola, Label: TITLE, Start: 10, End: 68
# ----------------------------------------
# Text: petrus abaelardus sequentia et hymnus per totus annus circulus in usus uirgo monasterium paraclitendo
#  - Entity: petrus abaelardus, Label: PERSON, Start: 0, End: 17
#  - Entity: sequentia et hymnus per totus annus circulus in usus uirgo monasterium paraclitendo, Label: TITLE, Start: 18, End: 101
# ----------------------------------------
# Text: petrus abaelardus carmen
#  - Entity: petrus abaelardus, Label: PERSON, Start: 0, End: 17
#  - Entity: carmen, Label: TITLE, Start: 18, End: 24
# ----------------------------------------
# Text: heloissum heloissa  problema cum mag . petrus abaelardus solutio
#  - Entity: heloissum, Label: PERSON, Start: 0, End: 9
#  - Entity: heloissa  problema cum mag . petrus abaelardus solutio, Label: TITLE, Start: 10, End: 64
# ----------------------------------------
# Text: petrus abaelardus epistola ad uirgo paraclitensis de studium littera
#  - Entity: petrus abaelardus, Label: PERSON, Start: 0, End: 17
#  - Entity: epistola ad uirgo paraclitensis de studium littera, Label: TITLE, Start: 18, End: 68
# ----------------------------------------
# Text: petrus abaelardus logicus ingredior
#  - Entity: petrus abaelardus, Label: PERSON, Start: 0, End: 17
#  - Entity: logicus ingredior, Label: TITLE, Start: 18, End: 35
# ----------------------------------------
# Text: petrus abaelardus dialecticus
#  - Entity: petrus abaelardus, Label: PERSON, Start: 0, End: 17
#  - Entity: dialecticus, Label: TITLE, Start: 18, End: 29
# ----------------------------------------
# Text: petrus abaelardus logicus noster petitio socius
#  - Entity: petrus abaelardus, Label: PERSON, Start: 0, End: 17
#  - Entity: logicus noster petitio socius, Label: TITLE, Start: 18, End: 47
# ----------------------------------------
# Text: petrus abaelardus tractatus de intellectus
#  - Entity: petrus abaelardus, Label: PERSON, Start: 0, End: 17
#  - Entity: tractatus de intellectus, Label: TITLE, Start: 18, End: 42
# ----------------------------------------
# Text: petrus abaelardus dialogus inter philosophus , iudaeus , et christianus
#  - Entity: petrus abaelardus, Label: PERSON, Start: 0, End: 17
#  - Entity: dialogus inter philosophus , iudaeus , et christianus, Label: TITLE, Start: 18, End: 71
# ----------------------------------------
# Text: eraycius puteanus de erycium nomen syntagma
#  - Entity: eraycius puteanus, Label: PERSON, Start: 0, End: 17
#  - Entity: de erycium nomen syntagma, Label: TITLE, Start: 18, End: 43
# ----------------------------------------
# Text: hadrianus castellensum uenatio
#  - Entity: hadrianus castellensum, Label: PERSON, Start: 0, End: 22
#  - Entity: uenatio, Label: TITLE, Start: 23, End: 30
# ----------------------------------------
# Text: uictor faustus oratio quinque
#  - Entity: uictor faustus, Label: PERSON, Start: 0, End: 14
#  - Entity: oratio quinque, Label: TITLE, Start: 15, End: 29
# ----------------------------------------
# Text: petrus bonus pretiosus margarita nouellus
#  - Entity: petrus bonus, Label: PERSON, Start: 0, End: 12
#  - Entity: pretiosus margarita nouellus, Label: TITLE, Start: 13, End: 41
# ----------------------------------------
# Text: christophorus longolus perduellio res defensio duo
#  - Entity: christophorus longolus, Label: PERSON, Start: 0, End: 22
#  - Entity: perduellio res defensio duo, Label: TITLE, Start: 23, End: 50
# ----------------------------------------
# Text: marcus antonius flaminius in liber psalmus breuis explanatio ad alexander farnesis , cardinalis amplus
#  - Entity: marcus antonius flaminius, Label: PERSON, Start: 0, End: 25
#  - Entity: in liber psalmus breuis explanatio ad alexander farnesis , cardinalis amplus, Label: TITLE, Start: 26, End: 102
# ----------------------------------------
# Text: petrus bems historia ueneta
#  - Entity: petrus bems, Label: PERSON, Start: 0, End: 11
#  - Entity: historia ueneta, Label: TITLE, Start: 12, End: 27
# ----------------------------------------
# Text:  budaeus de as et pars ius
#  - Entity:  budaeus, Label: PERSON, Start: 0, End: 8
#  - Entity: de as et pars ius, Label: TITLE, Start: 9, End: 26
# ----------------------------------------
# Text: iohannes iouianus pontanus epigramma duodecim
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: epigramma duodecim, Label: TITLE, Start: 27, End: 45
# ----------------------------------------
# Text: iohannes iouianus pontanus nenia duodecim
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: nenia duodecim, Label: TITLE, Start: 27, End: 41
# ----------------------------------------
# Text: iohannes iouianus pontanus tumulus liber i
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: tumulus liber i, Label: TITLE, Start: 27, End: 42
# ----------------------------------------
# Text: iohannes iouianus pontanus lepiden
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: lepiden, Label: TITLE, Start: 27, End: 34
# ----------------------------------------
# Text: iohannes iouianus pontanus de hortus hesperis siue de cultus citrior
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de hortus hesperis siue de cultus citrior, Label: TITLE, Start: 27, End: 68
# ----------------------------------------
# Text: iohannes iouianus pontanus de luna fragmentum
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de luna fragmentum, Label: TITLE, Start: 27, End: 45
# ----------------------------------------
# Text: iohannes iouianus pontanus de fortuna
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de fortuna, Label: TITLE, Start: 27, End: 37
# ----------------------------------------
# Text: iohannes iouianus pontanus liber de meteorum
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: liber de meteorum, Label: TITLE, Start: 27, End: 44
# ----------------------------------------
# Text: iohannes iouianus pontanus de immanitas
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de immanitas, Label: TITLE, Start: 27, End: 39
# ----------------------------------------
# Text: iohannes iouianus pontanus epistola
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: epistola, Label: TITLE, Start: 27, End: 35
# ----------------------------------------
# Text: iohannes iouianus pontanus de bellum neapolitanus
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de bellum neapolitanus, Label: TITLE, Start: 27, End: 49
# ----------------------------------------
# Text: iohannes iouianus pontanus de res coelestis liber xiu
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de res coelestis liber xiu, Label: TITLE, Start: 27, End: 53
# ----------------------------------------
# Text: iohannes iouianus pontanus dialogum
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: dialogum, Label: TITLE, Start: 27, End: 35
# ----------------------------------------
# Text: iohannes iouianus pontanus aegidus
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: aegidus, Label: TITLE, Start: 27, End: 34
# ----------------------------------------
# Text: iohannes iouianus pontanus actius
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: actius, Label: TITLE, Start: 27, End: 33
# ----------------------------------------
# Text: iohannes iouianus pontanus asinus
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: asinus, Label: TITLE, Start: 27, End: 33
# ----------------------------------------
# Text: iohannes iouianus pontanus antonius
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: antonius, Label: TITLE, Start: 27, End: 35
# ----------------------------------------
# Text: iohannes iouianus pontanus charon
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: charon, Label: TITLE, Start: 27, End: 33
# ----------------------------------------
# Text: iohannes iouianus pontanus de sermo liber uis
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de sermo liber uis, Label: TITLE, Start: 27, End: 45
# ----------------------------------------
# Text: iohannes iouianus pontanus commentatio in centum claudium ptolemaeus sententia
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: commentatio in centum claudium ptolemaeus sententia, Label: TITLE, Start: 27, End: 78
# ----------------------------------------
# Text: iohannes iouianus pontanus tractatus
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: tractatus, Label: TITLE, Start: 27, End: 36
# ----------------------------------------
# Text: iohannes iouianus pontanus de aspiratio
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de aspiratio, Label: TITLE, Start: 27, End: 39
# ----------------------------------------
# Text: iohannes iouianus pontanus de magnanimitas
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de magnanimitas, Label: TITLE, Start: 27, End: 42
# ----------------------------------------
# Text: iohannes iouianus pontanus de prudentia
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de prudentia, Label: TITLE, Start: 27, End: 39
# ----------------------------------------
# Text: iohannes iouianus pontanus de conuiuo
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de conuiuo, Label: TITLE, Start: 27, End: 37
# ----------------------------------------
# Text: iohannes iouianus pontanus de splendor
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de splendor, Label: TITLE, Start: 27, End: 38
# ----------------------------------------
# Text: iohannes iouianus pontanus de magnificentia
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de magnificentia, Label: TITLE, Start: 27, End: 43
# ----------------------------------------
# Text: iohannes iouianus pontanus de beneficentia
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de beneficentia, Label: TITLE, Start: 27, End: 42
# ----------------------------------------
# Text: iohannes iouianus pontanus de liberalitas
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de liberalitas, Label: TITLE, Start: 27, End: 41
# ----------------------------------------
# Text: iohannes iouianus pontanus de fortitudo
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de fortitudo, Label: TITLE, Start: 27, End: 39
# ----------------------------------------
# Text: iohannes iouianus pontanus de oboedientia
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de oboedientia, Label: TITLE, Start: 27, End: 41
# ----------------------------------------
# Text: iohannes iouianus pontanus de princeps
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de princeps, Label: TITLE, Start: 27, End: 38
# ----------------------------------------
# Text: iohannes iouianus pontanus carmen
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: carmen, Label: TITLE, Start: 27, End: 33
# ----------------------------------------
# Text: iohannes iouianus pontanus uranium siue de stella liber ut
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: uranium siue de stella liber ut, Label: TITLE, Start: 27, End: 58
# ----------------------------------------
# Text: iohannes iouianus pontanus hendecasyllabus siue baia liber ii
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: hendecasyllabus siue baia liber ii, Label: TITLE, Start: 27, End: 61
# ----------------------------------------
# Text: iohannes iouianus pontanus eridanus
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: eridanus, Label: TITLE, Start: 27, End: 35
# ----------------------------------------
# Text: iohannes iouianus pontanus meliseus
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: meliseus, Label: TITLE, Start: 27, End: 35
# ----------------------------------------
# Text: iohannes iouianus pontanus de amor coniugalis liber iii
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de amor coniugalis liber iii, Label: TITLE, Start: 27, End: 55
# ----------------------------------------
# Text: iohannes iouianus pontanus
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
# ----------------------------------------
# Text: iohannes iouianus pontanus
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
# ----------------------------------------
# Text: iohannes iouianus pontanus parthenopes siue amor liber ii
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: parthenopes siue amor liber ii, Label: TITLE, Start: 27, End: 57
# ----------------------------------------
# Text: iohannes iouianus pontanus lepiden
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: lepiden, Label: TITLE, Start: 27, End: 34
# ----------------------------------------
# Text: iohannes iouianus pontanus de meteorum
#  - Entity: iohannes iouianus pontanus, Label: PERSON, Start: 0, End: 26
#  - Entity: de meteorum, Label: TITLE, Start: 27, End: 38
# ----------------------------------------
# Text: petrus blesendo carmen
#  - Entity: petrus blesendo, Label: PERSON, Start: 0, End: 15
#  - Entity: carmen, Label: TITLE, Start: 16, End: 22
# ----------------------------------------
# Text: thomas de aquinus summus theologia
#  - Entity: thomas de aquinus, Label: PERSON, Start: 0, End: 17
#  - Entity: summus theologia, Label: TITLE, Start: 18, End: 34
# ----------------------------------------
# Text: quoduultdeus carthaginiendo sermo
#  - Entity: quoduultdeus carthaginiendo, Label: PERSON, Start: 0, End: 27
#  - Entity: sermo, Label: TITLE, Start: 28, End: 33
# ----------------------------------------
# Text: laurenter de brundisia lutheranisma hypotyposum
#  - Entity: laurenter de brundisia, Label: PERSON, Start: 0, End: 22
#  - Entity: lutheranisma hypotyposum, Label: TITLE, Start: 23, End: 47
# ----------------------------------------
# Text: hugo de sanctus uictor chronicon pontifex et imperator
#  - Entity: hugo de sanctus uictor, Label: PERSON, Start: 0, End: 22
#  - Entity: chronicon pontifex et imperator, Label: TITLE, Start: 23, End: 54
# ----------------------------------------
# Text: aelius dono ars grammaticus
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: ars grammaticus, Label: TITLE, Start: 12, End: 27
# ----------------------------------------
# Text: doctor irrefragabilis summus theologicus
#  - Entity: doctor irrefragabilis, Label: PERSON, Start: 0, End: 21
#  - Entity: summus theologicus, Label: TITLE, Start: 22, End: 40
# ----------------------------------------
# Text: sulpica apollinaris , supilicius carthaginendo  terentius comoedia
#  - Entity: sulpica apollinaris , supilicius carthaginendo, Label: PERSON, Start: 0, End: 46
#  - Entity:  terentius comoedia, Label: TITLE, Start: 47, End: 66
# ----------------------------------------
# Text: publius cornelius dolabellum epistula . ab p. cornelius dolabellum
#  - Entity: publius cornelius dolabellum, Label: PERSON, Start: 0, End: 28
#  - Entity: epistula . ab p. cornelius dolabellum, Label: TITLE, Start: 29, End: 66
# ----------------------------------------
# Text: gaius iulius caesar de analogia ad m. tullius cicero
#  - Entity: gaius iulius caesar, Label: PERSON, Start: 0, End: 19
#  - Entity: de analogia ad m. tullius cicero, Label: TITLE, Start: 20, End: 52
# ----------------------------------------
# Text: gnaeus matus epistula . ad cn.t matus
#  - Entity: gnaeus matus, Label: PERSON, Start: 0, End: 12
#  - Entity: epistula . ad cn.t matus, Label: TITLE, Start: 13, End: 37
# ----------------------------------------
# Text: saluius iulianus iurisprudentia
#  - Entity: saluius iulianus, Label: PERSON, Start: 0, End: 16
#  - Entity: iurisprudentia, Label: TITLE, Start: 17, End: 31
# ----------------------------------------
# Text: titus aelius hadrianus antoninus augustus pius epistula . ab antoninus pius
#  - Entity: titus aelius hadrianus antoninus augustus pius, Label: PERSON, Start: 0, End: 46
#  - Entity: epistula . ab antoninus pius, Label: TITLE, Start: 47, End: 75
# ----------------------------------------
# Text: licinius rufinus iurisprudentia
#  - Entity: licinius rufinus, Label: PERSON, Start: 0, End: 16
#  - Entity: iurisprudentia, Label: TITLE, Start: 17, End: 31
# ----------------------------------------
# Text: gaius aburnus ualeo iurisprudentia
#  - Entity: gaius aburnus ualeo, Label: PERSON, Start: 0, End: 19
#  - Entity: iurisprudentia, Label: TITLE, Start: 20, End: 34
# ----------------------------------------
# Text: titus flauior caesar domitianus augustus epistula . ab domitianum
#  - Entity: titus flauior caesar domitianus augustus, Label: PERSON, Start: 0, End: 40
#  - Entity: epistula . ab domitianum, Label: TITLE, Start: 41, End: 65
# ----------------------------------------
# Text: ulpius marcellus iurisprudentia
#  - Entity: ulpius marcellus, Label: PERSON, Start: 0, End: 16
#  - Entity: iurisprudentia, Label: TITLE, Start: 17, End: 31
# ----------------------------------------
# Text: domis afer fragmentum in quint. instio .
#  - Entity: domis afer, Label: PERSON, Start: 0, End: 10
#  - Entity: fragmentum in quint. instio ., Label: TITLE, Start: 11, End: 40
# ----------------------------------------
# Text: lucius lucceius epistula . ab l.s lucceius
#  - Entity: lucius lucceius, Label: PERSON, Start: 0, End: 15
#  - Entity: epistula . ab l.s lucceius, Label: TITLE, Start: 16, End: 42
# ----------------------------------------
# Text: lucius aurelus uerus epistula . ab l.s aurelium uero
#  - Entity: lucius aurelus uerus, Label: PERSON, Start: 0, End: 20
#  - Entity: epistula . ab l.s aurelium uero, Label: TITLE, Start: 21, End: 52
# ----------------------------------------
# Text: publius cornelius lentulus spinther epistula . ab p. cornelius lentulus spintherus
#  - Entity: publius cornelius lentulus spinther, Label: PERSON, Start: 0, End: 35
#  - Entity: epistula . ab p. cornelius lentulus spintherus, Label: TITLE, Start: 36, End: 82
# ----------------------------------------
# Text: quintus caecile metellus celer epistula . ab q. caecilium metellus celer
#  - Entity: quintus caecile metellus celer, Label: PERSON, Start: 0, End: 30
#  - Entity: epistula . ab q. caecilium metellus celer, Label: TITLE, Start: 31, End: 72
# ----------------------------------------
# Text: herennius modestinus iurisprudentia
#  - Entity: herennius modestinus, Label: PERSON, Start: 0, End: 20
#  - Entity: iurisprudentia, Label: TITLE, Start: 21, End: 35
# ----------------------------------------
# Text: terenter clemens iurisprudentia
#  - Entity: terenter clemens, Label: PERSON, Start: 0, End: 16
#  - Entity: iurisprudentia, Label: TITLE, Start: 17, End: 31
# ----------------------------------------
# Text: tarruntenus paternus iurisprudentia
#  - Entity: tarruntenus paternus, Label: PERSON, Start: 0, End: 20
#  - Entity: iurisprudentia, Label: TITLE, Start: 21, End: 35
# ----------------------------------------
# Text: arrius menander iurisprudentia
#  - Entity: arrius menander, Label: PERSON, Start: 0, End: 15
#  - Entity: iurisprudentia, Label: TITLE, Start: 16, End: 30
# ----------------------------------------
# Text: claudus  iurisprudentia
#  - Entity: iurisprudentia, Label: TITLE, Start: 9, End: 23
# ----------------------------------------
# Text: manlius curius epistula . ab m’.s curius
#  - Entity: manlius curius, Label: PERSON, Start: 0, End: 14
#  - Entity: epistula . ab m’.s curius, Label: TITLE, Start: 15, End: 40
# ----------------------------------------
# Text: iunus mauricianus iurisprudentia
#  - Entity: iunus mauricianus, Label: PERSON, Start: 0, End: 17
#  - Entity: iurisprudentia, Label: TITLE, Start: 18, End: 32
# ----------------------------------------
# Text: iauolenus priscus iurisprudentia
#  - Entity: iauolenus priscus, Label: PERSON, Start: 0, End: 17
#  - Entity: iurisprudentia, Label: TITLE, Start: 18, End: 32
# ----------------------------------------
# Text: marcus claudus marcellus epistula . ab m. claudius marcellus
#  - Entity: marcus claudus marcellus, Label: PERSON, Start: 0, End: 24
#  - Entity: epistula . ab m. claudius marcellus, Label: TITLE, Start: 25, End: 60
# ----------------------------------------
# Text: quintus caecile nepos metellus epistula . ab q. caecilium nepos metellus
#  - Entity: quintus caecile nepos metellus, Label: PERSON, Start: 0, End: 30
#  - Entity: epistula . ab q. caecilium nepos metellus, Label: TITLE, Start: 31, End: 72
# ----------------------------------------
# Text: decimus iunius brutus albinus epistula . ab decimus iunius brutus albinus
#  - Entity: decimus iunius brutus albinus, Label: PERSON, Start: 0, End: 29
#  - Entity: epistula . ab decimus iunius brutus albinus, Label: TITLE, Start: 30, End: 73
# ----------------------------------------
# Text: publius uatinus epistula . ab p. uatinium
#  - Entity: publius uatinus, Label: PERSON, Start: 0, End: 15
#  - Entity: epistula . ab p. uatinium, Label: TITLE, Start: 16, End: 41
# ----------------------------------------
# Text: claudus tryphoninus iurisprudentia
#  - Entity: claudus tryphoninus, Label: PERSON, Start: 0, End: 19
#  - Entity: iurisprudentia, Label: TITLE, Start: 20, End: 34
# ----------------------------------------
# Text: uenuleius  iurisprudentia
#  - Entity: iurisprudentia, Label: TITLE, Start: 11, End: 25
# ----------------------------------------
# Text: marcus cocceius neruus caesar augustus epistula . ab neruus
#  - Entity: marcus cocceius neruus caesar augustus, Label: PERSON, Start: 0, End: 38
#  - Entity: epistula . ab neruus, Label: TITLE, Start: 39, End: 59
# ----------------------------------------
# Text: gaius cassus hemina historia
#  - Entity: gaius cassus hemina, Label: PERSON, Start: 0, End: 19
#  - Entity: historia, Label: TITLE, Start: 20, End: 28
# ----------------------------------------
# Text: marcus aemilis lepidus epistula . ab m. lepidus
#  - Entity: marcus aemilis lepidus, Label: PERSON, Start: 0, End: 22
#  - Entity: epistula . ab m. lepidus, Label: TITLE, Start: 23, End: 47
# ----------------------------------------
# Text: cae trebonus epistula . ab c. trebonius
#  - Entity: cae trebonus, Label: PERSON, Start: 0, End: 12
#  - Entity: epistula . ab c. trebonius, Label: TITLE, Start: 13, End: 39
# ----------------------------------------
# Text: proculus  iurisprudentia
#  - Entity: iurisprudentia, Label: TITLE, Start: 10, End: 24
# ----------------------------------------
# Text: papirius iustus iurisprudentia
#  - Entity: papirius iustus, Label: PERSON, Start: 0, End: 15
#  - Entity: iurisprudentia, Label: TITLE, Start: 16, End: 30
# ----------------------------------------
# Text: l.s aemiliter  .  . paulus oratio
#  - Entity: l.s aemiliter  .  . paulus, Label: PERSON, Start: 0, End: 26
#  - Entity: oratio, Label: TITLE, Start: 27, End: 33
# ----------------------------------------
# Text: m. ualerius messalla coruinus grammaticus
#  - Entity: m. ualerius messalla coruinus, Label: PERSON, Start: 0, End: 29
#  - Entity: grammaticus, Label: TITLE, Start: 30, End: 41
# ----------------------------------------
# Text: m. ualerius messalla rufus iurisprudentia
#  - Entity: m. ualerius messalla rufus, Label: PERSON, Start: 0, End: 26
#  - Entity: iurisprudentia, Label: TITLE, Start: 27, End: 41
# ----------------------------------------
# Text: marcus tullius cicero singulus uox ex incertus liber
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: singulus uox ex incertus liber, Label: TITLE, Start: 22, End: 52
# ----------------------------------------
# Text: marcus tullius cicero de uirtus
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: de uirtus, Label: TITLE, Start: 22, End: 31
# ----------------------------------------
# Text: marcus tullius cicero protagora
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: protagora, Label: TITLE, Start: 22, End: 31
# ----------------------------------------
# Text: marcus tullius cicero oeconomicus
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: oeconomicus, Label: TITLE, Start: 22, End: 33
# ----------------------------------------
# Text: marcus tullius cicero de consilium suus
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: de consilium suus, Label: TITLE, Start: 22, End: 39
# ----------------------------------------
# Text: marcus tullius cicero consolatio
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: consolatio, Label: TITLE, Start: 22, End: 32
# ----------------------------------------
# Text: marcus tullius cicero catus
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: catus, Label: TITLE, Start: 22, End: 27
# ----------------------------------------
# Text: marcus tullius cicero de augurium
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: de augurium, Label: TITLE, Start: 22, End: 33
# ----------------------------------------
# Text: marcus tullius cicero chorographia
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: chorographia, Label: TITLE, Start: 22, End: 34
# ----------------------------------------
# Text: marcus tullius cicero marius
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: marius, Label: TITLE, Start: 22, End: 28
# ----------------------------------------
# Text: marcus tullius cicero limon
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: limon, Label: TITLE, Start: 22, End: 27
# ----------------------------------------
# Text: marcus tullius cicero de gloria
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: de gloria, Label: TITLE, Start: 22, End: 31
# ----------------------------------------
# Text: marcus tullius cicero epigramma
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: epigramma, Label: TITLE, Start: 22, End: 31
# ----------------------------------------
# Text: marcus tullius cicero elegia talemaso ( dubo . )
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: elegia talemaso ( dubo . ), Label: TITLE, Start: 22, End: 48
# ----------------------------------------
# Text: marcus tullius cicero alcyon
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: alcyon, Label: TITLE, Start: 22, End: 28
# ----------------------------------------
# Text: pompeius trogus fragmentum
#  - Entity: pompeius trogus, Label: PERSON, Start: 0, End: 15
#  - Entity: fragmentum, Label: TITLE, Start: 16, End: 26
# ----------------------------------------
# Text: marcus antonius triumuir epistula
#  - Entity: marcus antonius triumuir, Label: PERSON, Start: 0, End: 24
#  - Entity: epistula, Label: TITLE, Start: 25, End: 33
# ----------------------------------------
# Text: quintus fabius pictor oratio
#  - Entity: quintus fabius pictor, Label: PERSON, Start: 0, End: 21
#  - Entity: oratio, Label: TITLE, Start: 22, End: 28
# ----------------------------------------
# Text: imperator caesar neruus traianus diuus neruus filius augustus epistula ab traianum ad plinium
#  - Entity: imperator caesar neruus traianus diuus neruus filius augustus, Label: PERSON, Start: 0, End: 61
#  - Entity: epistula ab traianum ad plinium, Label: TITLE, Start: 62, End: 93
# ----------------------------------------
# Text: albinouanus pedo fragmentum
#  - Entity: albinouanus pedo, Label: PERSON, Start: 0, End: 16
#  - Entity: fragmentum, Label: TITLE, Start: 17, End: 27
# ----------------------------------------
# Text: quintus caecile metellus pius fragmentum in macrobius
#  - Entity: quintus caecile metellus pius, Label: PERSON, Start: 0, End: 29
#  - Entity: fragmentum in macrobius, Label: TITLE, Start: 30, End: 53
# ----------------------------------------
# Text: marcus iunius gracchanus iurisprudentia
#  - Entity: marcus iunius gracchanus, Label: PERSON, Start: 0, End: 24
#  - Entity: iurisprudentia, Label: TITLE, Start: 25, End: 39
# ----------------------------------------
# Text: porcius licinus grammaticus
#  - Entity: porcius licinus, Label: PERSON, Start: 0, End: 15
#  - Entity: grammaticus, Label: TITLE, Start: 16, End: 27
# ----------------------------------------
# Text: iulius paulus fragmentum
#  - Entity: iulius paulus, Label: PERSON, Start: 0, End: 13
#  - Entity: fragmentum, Label: TITLE, Start: 14, End: 24
# ----------------------------------------
# Text: marcus tullius cicero oratio pridie quam in exilium eo
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: oratio pridie quam in exilium eo, Label: TITLE, Start: 22, End: 54
# ----------------------------------------
# Text: marcus tullius cicero pro l.s uarenus
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: pro l.s uarenus, Label: TITLE, Start: 22, End: 37
# ----------------------------------------
# Text: marcus tullius cicero in toga candidus
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: in toga candidus, Label: TITLE, Start: 22, End: 38
# ----------------------------------------
# Text: marcus tullius cicero pro oppium
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: pro oppium, Label: TITLE, Start: 22, End: 32
# ----------------------------------------
# Text: marcus tullius cicero contra contio q. metellus
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: contra contio q. metellus, Label: TITLE, Start: 22, End: 47
# ----------------------------------------
# Text: marcus tullius cicero pro c. manilium
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: pro c. manilium, Label: TITLE, Start: 22, End: 37
# ----------------------------------------
# Text: marcus tullius cicero pro q. gallium
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: pro q. gallium, Label: TITLE, Start: 22, End: 36
# ----------------------------------------
# Text: marcus tullius cicero pro fundanium
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: pro fundanium, Label: TITLE, Start: 22, End: 35
# ----------------------------------------
# Text: marcus tullius cicero pro cornelium
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: pro cornelium, Label: TITLE, Start: 22, End: 35
# ----------------------------------------
# Text: marcus tullius cicero in p. clodium et c. curio
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: in p. clodium et c. curio, Label: TITLE, Start: 22, End: 47
# ----------------------------------------
# Text: marcus tullius cicero de rex alexandrinus
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: de rex alexandrinus, Label: TITLE, Start: 22, End: 41
# ----------------------------------------
# Text: marcus tullius cicero interrogatio de aer alienus milo
#  - Entity: marcus tullius cicero, Label: PERSON, Start: 0, End: 21
#  - Entity: interrogatio de aer alienus milo, Label: TITLE, Start: 22, End: 54
# ----------------------------------------
# Text:  pompeius magnus epistula ab gns . pompeius magnus
#  - Entity:  pompeius magnus, Label: PERSON, Start: 0, End: 16
#  - Entity: epistula ab gns . pompeius magnus, Label: TITLE, Start: 17, End: 50
# ----------------------------------------
# Text: seruius sulpicius rufus epistula ab seruio sulpicius rufus
#  - Entity: seruius sulpicius rufus, Label: PERSON, Start: 0, End: 23
#  - Entity: epistula ab seruio sulpicius rufus, Label: TITLE, Start: 24, End: 58
# ----------------------------------------
# Text: quintus tullius cicero epistula ab q. tullius cicero
#  - Entity: quintus tullius cicero, Label: PERSON, Start: 0, End: 22
#  - Entity: epistula ab q. tullius cicero, Label: TITLE, Start: 23, End: 52
# ----------------------------------------
# Text: gaius asinius pollius epistula ab c. asinium pollio
#  - Entity: gaius asinius pollius, Label: PERSON, Start: 0, End: 21
#  - Entity: epistula ab c. asinium pollio, Label: TITLE, Start: 22, End: 51
# ----------------------------------------
# Text: lucius munas plancus epistula ab l.s munatio plancus
#  - Entity: lucius munas plancus, Label: PERSON, Start: 0, End: 20
#  - Entity: epistula ab l.s munatio plancus, Label: TITLE, Start: 21, End: 52
# ----------------------------------------
# Text: eugenius toletanus dracontium liber recognitio
#  - Entity: eugenius toletanus, Label: PERSON, Start: 0, End: 18
#  - Entity: dracontium liber recognitio, Label: TITLE, Start: 19, End: 46
# ----------------------------------------
# Text: blossius aemilius dracontius dracontium liber recognitio
#  - Entity: blossius aemilius dracontius, Label: PERSON, Start: 0, End: 28
#  - Entity: dracontium liber recognitio, Label: TITLE, Start: 29, End: 56
# ----------------------------------------
# Text: eucherius  de situs hierusolimitanus urbs ( dubo . )
#  - Entity: de situs hierusolimitanus urbs ( dubo . ), Label: TITLE, Start: 11, End: 52
# ----------------------------------------
# Text: publius ouidius nasus epistula sapphus ( dubo . )
#  - Entity: publius ouidius nasus, Label: PERSON, Start: 0, End: 21
#  - Entity: epistula sapphus ( dubo . ), Label: TITLE, Start: 22, End: 49
# ----------------------------------------
# Text: sulpicius seuerus epistola septem ( dubo . )
#  - Entity: sulpicius seuerus, Label: PERSON, Start: 0, End: 17
#  - Entity: epistola septem ( dubo . ), Label: TITLE, Start: 18, End: 44
# ----------------------------------------
# Text: alexander trallianus alexander trallianum de medicina ( practicus ) ( dubo . )
#  - Entity: alexander trallianus, Label: PERSON, Start: 0, End: 20
#  - Entity: alexander trallianum de medicina ( practicus ) ( dubo . ), Label: TITLE, Start: 21, End: 78
# ----------------------------------------
# Text: gualterus mappus carmen ( dub . )
#  - Entity: gualterus mappus, Label: PERSON, Start: 0, End: 16
#  - Entity: carmen ( dub . ), Label: TITLE, Start: 17, End: 33
# ----------------------------------------
# Text: aurelus augustinus soliloquium anima ad deus ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: soliloquium anima ad deus ( dubo . ), Label: TITLE, Start: 19, End: 55
# ----------------------------------------
# Text: aurelus augustinus sermo de mysterium baptisimo ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: sermo de mysterium baptisimo ( dubo . ), Label: TITLE, Start: 19, End: 58
# ----------------------------------------
# Text: aurelus augustinus tractatus de oratio et eleemosyna ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: tractatus de oratio et eleemosyna ( dubo . ), Label: TITLE, Start: 19, End: 63
# ----------------------------------------
# Text: aurelus augustinus speculum peccator ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: speculum peccator ( dubo . ), Label: TITLE, Start: 19, End: 47
# ----------------------------------------
# Text: aurelus augustinus sermo de generalitas eleemosyna ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: sermo de generalitas eleemosyna ( dubo . ), Label: TITLE, Start: 19, End: 61
# ----------------------------------------
# Text: aurelus augustinus miscellaneus sententia ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: miscellaneus sententia ( dubo . ), Label: TITLE, Start: 19, End: 52
# ----------------------------------------
# Text: aurelus augustinus dialogus quaestio lxu ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: dialogus quaestio lxu ( dubo . ), Label: TITLE, Start: 19, End: 51
# ----------------------------------------
# Text: aurelus augustinus de uisitatio infirmus ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de uisitatio infirmus ( dubo . ), Label: TITLE, Start: 19, End: 51
# ----------------------------------------
# Text: aurelus augustinus de diligendus deus ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de diligendus deus ( dubo . ), Label: TITLE, Start: 19, End: 48
# ----------------------------------------
# Text: aurelus augustinus tractatus de septem uitium et septem donum spiritus sanctus ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: tractatus de septem uitium et septem donum spiritus sanctus ( dubo . ), Label: TITLE, Start: 19, End: 89
# ----------------------------------------
# Text: aurelus augustinus tractatus de creatio primus homo ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: tractatus de creatio primus homo ( dubo . ), Label: TITLE, Start: 19, End: 62
# ----------------------------------------
# Text: aurelus augustinus speculum ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: speculum ( dubo . ), Label: TITLE, Start: 19, End: 38
# ----------------------------------------
# Text: aurelus augustinus sermo quattuor sanctus augustinus attributum ( dub . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: sermo quattuor sanctus augustinus attributum ( dub . ), Label: TITLE, Start: 19, End: 73
# ----------------------------------------
# Text: aurelus augustinus sermo ad frater in eremus commoror et quidam alius ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: sermo ad frater in eremus commoror et quidam alius ( dubo . ), Label: TITLE, Start: 19, End: 80
# ----------------------------------------
# Text: aurelus augustinus sermo de is quod neophytus ex oleum sanctus auris et naris ab sacerdos illinio ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: sermo de is quod neophytus ex oleum sanctus auris et naris ab sacerdos illinio ( dubo . ), Label: TITLE, Start: 19, End: 108
# ----------------------------------------
# Text: aurelus augustinus sermo de bonus disciplina ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: sermo de bonus disciplina ( dubo . ), Label: TITLE, Start: 19, End: 55
# ----------------------------------------
# Text: aurelus augustinus scala paradisus ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: scala paradisus ( dubo . ), Label: TITLE, Start: 19, End: 45
# ----------------------------------------
# Text: aurelus augustinus meditatio ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: meditatio ( dubo . ), Label: TITLE, Start: 19, End: 39
# ----------------------------------------
# Text: aurelus augustinus de uita christianus ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de uita christianus ( dubo . ), Label: TITLE, Start: 19, End: 49
# ----------------------------------------
# Text: aurelus augustinus de trinitas et unitas deus ( dub . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de trinitas et unitas deus ( dub . ), Label: TITLE, Start: 19, End: 55
# ----------------------------------------
# Text: aurelus augustinus de sobrietas et castitas ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de sobrietas et castitas ( dubo . ), Label: TITLE, Start: 19, End: 54
# ----------------------------------------
# Text: aurelus augustinus de rectitudo catholicus conuersatio tractatus ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de rectitudo catholicus conuersatio tractatus ( dubo . ), Label: TITLE, Start: 19, End: 75
# ----------------------------------------
# Text: aurelus augustinus de fides ad petrus siue de regula uerus fides ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de fides ad petrus siue de regula uerus fides ( dubo . ), Label: TITLE, Start: 19, End: 75
# ----------------------------------------
# Text: aurelus augustinus de essentia diuinitas ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de essentia diuinitas ( dubo . ), Label: TITLE, Start: 19, End: 51
# ----------------------------------------
# Text: aurelus augustinus de duodecim abusio gradus ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de duodecim abusio gradus ( dubo . ), Label: TITLE, Start: 19, End: 55
# ----------------------------------------
# Text: aurelus augustinus de assumptio beatus marius uirgo ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de assumptio beatus marius uirgo ( dubo . ), Label: TITLE, Start: 19, End: 62
# ----------------------------------------
# Text: aurelus augustinus ( tractatus ) de duodecim lapis ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: ( tractatus ) de duodecim lapis ( dubo . ), Label: TITLE, Start: 19, End: 61
# ----------------------------------------
# Text: aurelus augustinus soliloquium adscriptus caput postremus ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: soliloquium adscriptus caput postremus ( dubo . ), Label: TITLE, Start: 19, End: 68
# ----------------------------------------
# Text: aurelus augustinus sermo de uanitas saeculum ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: sermo de uanitas saeculum ( dubo . ), Label: TITLE, Start: 19, End: 55
# ----------------------------------------
# Text: aurelus augustinus de unitas sanctus trinitas dialogus ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de unitas sanctus trinitas dialogus ( dubo . ), Label: TITLE, Start: 19, End: 65
# ----------------------------------------
# Text: aurelus augustinus de substantia dilectio ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de substantia dilectio ( dubo . ), Label: TITLE, Start: 19, End: 52
# ----------------------------------------
# Text: aurelus augustinus de salutaris documentum ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: de salutaris documentum ( dubo . ), Label: TITLE, Start: 19, End: 53
# ----------------------------------------
# Text: felix i epistola ( dubo . )
#  - Entity: felix i, Label: PERSON, Start: 0, End: 7
#  - Entity: epistola ( dubo . ), Label: TITLE, Start: 8, End: 27
# ----------------------------------------
# Text: eusebius sophronius hieronymus de deus et nomen is ( dubo . )
#  - Entity: eusebius sophronius hieronymus, Label: PERSON, Start: 0, End: 30
#  - Entity: de deus et nomen is ( dubo . ), Label: TITLE, Start: 31, End: 61
# ----------------------------------------
# Text: marcus scribo dubius auctoritas ( dubo . )
#  - Entity: marcus, Label: PERSON, Start: 0, End: 6
#  - Entity: scribo dubius auctoritas ( dubo . ), Label: TITLE, Start: 7, End: 42
# ----------------------------------------
# Text: iacobus sprenger malleus maleficus ( dubo . )
#  - Entity: iacobus sprenger, Label: PERSON, Start: 0, End: 16
#  - Entity: malleus maleficus ( dubo . ), Label: TITLE, Start: 17, End: 45
# ----------------------------------------
# Text: aurelus augustinus tractatus de charitas ( dubo . )
#  - Entity: aurelus augustinus, Label: PERSON, Start: 0, End: 18
#  - Entity: tractatus de charitas ( dubo . ), Label: TITLE, Start: 19, End: 51
# ----------------------------------------
# Text: aurelus augustinus sermo de contemptus mundus ( dubo . )
# ...
# ----------------------------------------
# Text: anastasiter i epistola duo anastasius perperam attribuo
#  - Entity: anastasiter i, Label: PERSON, Start: 0, End: 13
#  - Entity: epistola duo anastasius perperam attribuo, Label: TITLE, Start: 14, End: 55
# ----------------------------------------
# Text: anastasiter i epistola et decretum
#  - Entity: anastasiter i, Label: PERSON, Start: 0, End: 13
#  - Entity: epistola et decretum, Label: TITLE, Start: 14, End: 34
# ----------------------------------------
# Text: anastasiter i epistola anastasius romanus urbs episcopus ad  hierosolymus episcopus
#  - Entity: anastasiter i, Label: PERSON, Start: 0, End: 13
#  - Entity: epistola anastasius romanus urbs episcopus ad  hierosolymus episcopus, Label: TITLE, Start: 14, End: 83
# ----------------------------------------
# Text: aelius dono commentum terentium : andria
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: commentum terentium : andria, Label: TITLE, Start: 12, End: 40
# ----------------------------------------
# Text: aelius dono commentum terentium : eunuchus
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: commentum terentium : eunuchus, Label: TITLE, Start: 12, End: 42
# ----------------------------------------
# Text: aelius dono commentum terentium : hecyra
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: commentum terentium : hecyra, Label: TITLE, Start: 12, End: 40
# ----------------------------------------
# Text: aelius dono commentum terentium : phormius
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: commentum terentium : phormius, Label: TITLE, Start: 12, End: 42
# ----------------------------------------
# Text: aelius dono ars grammaticus i
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: ars grammaticus i, Label: TITLE, Start: 12, End: 29
# ----------------------------------------
# Text: aelius dono excerbo de comoedia
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: excerbo de comoedia, Label: TITLE, Start: 12, End: 31
# ----------------------------------------
# Text: aelius dono ars grammaticus is
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: ars grammaticus is, Label: TITLE, Start: 12, End: 30
# ----------------------------------------
# Text: aelius dono ars grammaticus iii
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: ars grammaticus iii, Label: TITLE, Start: 12, End: 31
# ----------------------------------------
# Text: aelius dono ars grammaticus iu
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: ars grammaticus iu, Label: TITLE, Start: 12, End: 30
# ----------------------------------------
# Text: aelius dono epistula ad lucius munatius
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: epistula ad lucius munatius, Label: TITLE, Start: 12, End: 39
# ----------------------------------------
# Text: aelius dono uita terentium
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: uita terentium, Label: TITLE, Start: 12, End: 26
# ----------------------------------------
# Text: aelius dono uita uergilius
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: uita uergilius, Label: TITLE, Start: 12, End: 26
# ----------------------------------------
# Text: aquila romanus de figura sententia et elocutio liber
#  - Entity: aquila romanus, Label: PERSON, Start: 0, End: 14
#  - Entity: de figura sententia et elocutio liber, Label: TITLE, Start: 15, End: 52
# ----------------------------------------
# Text: arnobius iunus conflictus cum serapio
#  - Entity: arnobius iunus, Label: PERSON, Start: 0, End: 14
#  - Entity: conflictus cum serapio, Label: TITLE, Start: 15, End: 37
# ----------------------------------------
# Text: arnobius iunus expositiuncula in euangelium iohannes euangelista , matthaeus , et luca
#  - Entity: arnobius iunus, Label: PERSON, Start: 0, End: 14
#  - Entity: expositiuncula in euangelium iohannes euangelista , matthaeus , et luca, Label: TITLE, Start: 15, End: 86
# ----------------------------------------
# Text: arnobius iunus liber ad gregoria in palatium constituo
#  - Entity: arnobius iunus, Label: PERSON, Start: 0, End: 14
#  - Entity: liber ad gregoria in palatium constituo, Label: TITLE, Start: 15, End: 54
# ----------------------------------------
# Text: arnobius iunus praedestino
#  - Entity: arnobius iunus, Label: PERSON, Start: 0, End: 14
#  - Entity: praedestino, Label: TITLE, Start: 15, End: 26
# ----------------------------------------
# Text: arnobius iunus commentarius in psalmus
#  - Entity: arnobius iunus, Label: PERSON, Start: 0, End: 14
#  - Entity: commentarius in psalmus, Label: TITLE, Start: 15, End: 38
# ----------------------------------------
# Text: ambrosiaster commentarius in paulum epistula ad romanus
#  - Entity: ambrosiaster, Label: PERSON, Start: 0, End: 12
#  - Entity: commentarius in paulum epistula ad romanus, Label: TITLE, Start: 13, End: 55
# ----------------------------------------
# Text: ambrosiaster commentarius in paulus epistula ad galo , ad ephesius , ad philippensis , ad colossensis , ad thessalonicensis , ad timotheus , ad titium , ad philemo
#  - Entity: ambrosiaster, Label: PERSON, Start: 0, End: 12
#  - Entity: commentarius in paulus epistula ad galo , ad ephesius , ad philippensis , ad colossensis , ad thessalonicensis , ad timotheus , ad titium , ad philemo, Label: TITLE, Start: 13, End: 163
# ----------------------------------------
# Text: amoenus in leontis episcopus reditus  ecclesia acrostichus
#  - Entity: amoenus, Label: PERSON, Start: 0, End: 7
#  - Entity: in leontis episcopus reditus  ecclesia acrostichus, Label: TITLE, Start: 8, End: 58
# ----------------------------------------
# Text: ambrosiaster quaestio uetus et nosco testamentum
#  - Entity: ambrosiaster, Label: PERSON, Start: 0, End: 12
#  - Entity: quaestio uetus et nosco testamentum, Label: TITLE, Start: 13, End: 48
# ----------------------------------------
# Text: amoenus enchiridion uetus et nosco testamentum
#  - Entity: amoenus, Label: PERSON, Start: 0, End: 7
#  - Entity: enchiridion uetus et nosco testamentum, Label: TITLE, Start: 8, End: 46
# ----------------------------------------
# Text: amoenus aegyptius deus martinus inuoco . tempestas periculum effugio
#  - Entity: amoenus, Label: PERSON, Start: 0, End: 7
#  - Entity: aegyptius deus martinus inuoco . tempestas periculum effugio, Label: TITLE, Start: 8, End: 68
# ----------------------------------------
# Text: ammianus marcellinus res gero liber qui supersum
#  - Entity: ammianus marcellinus, Label: PERSON, Start: 0, End: 20
#  - Entity: res gero liber qui supersum, Label: TITLE, Start: 21, End: 48
# ----------------------------------------
# Text: lucius apuleius madaurendo de deus socratus
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: de deus socratus, Label: TITLE, Start: 27, End: 43
# ----------------------------------------
# Text: lucius apuleius madaurendo de plato et is dogma
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: de plato et is dogma, Label: TITLE, Start: 27, End: 47
# ----------------------------------------
# Text: lucius apuleius madaurendo anechomenus
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: anechomenus, Label: TITLE, Start: 27, End: 38
# ----------------------------------------
# Text: lucius apuleius madaurendo de deus socratus ,  . ( dubo . )
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: de deus socratus ,  . ( dubo . ), Label: TITLE, Start: 27, End: 59
# ----------------------------------------
# Text: lucius apuleius madaurendo de mundus
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: de mundus, Label: TITLE, Start: 27, End: 36
# ----------------------------------------
# Text: lucius apuleius madaurendo fragmentum
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: fragmentum, Label: TITLE, Start: 27, End: 37
# ----------------------------------------
# Text: lucius apuleius madaurendo metamorphosis
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: metamorphosis, Label: TITLE, Start: 27, End: 40
# ----------------------------------------
# Text: lucius apuleius madaurendo pereo hermeneias ( de interpretatio )
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: pereo hermeneias ( de interpretatio ), Label: TITLE, Start: 27, End: 64
# ----------------------------------------
# Text: lucius apuleius madaurendo carmen
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: carmen, Label: TITLE, Start: 27, End: 33
# ----------------------------------------
# Text: lucius apuleius madaurendo floridus
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: floridus, Label: TITLE, Start: 27, End: 35
# ----------------------------------------
# Text: aelius dono praefatio commentarium in uergilius ecloga deperdo
#  - Entity: aelius dono, Label: PERSON, Start: 0, End: 11
#  - Entity: praefatio commentarium in uergilius ecloga deperdo, Label: TITLE, Start: 12, End: 62
# ----------------------------------------
# Text: arator subdiaconus epistola idem ad uigilius
#  - Entity: arator subdiaconus, Label: PERSON, Start: 0, End: 18
#  - Entity: epistola idem ad uigilius, Label: TITLE, Start: 19, End: 44
# ----------------------------------------
# Text: arator subdiaconus historia apostolicus
#  - Entity: arator subdiaconus, Label: PERSON, Start: 0, End: 18
#  - Entity: historia apostolicus, Label: TITLE, Start: 19, End: 39
# ----------------------------------------
# Text: antoninus placentinus itinerarium
#  - Entity: antoninus placentinus, Label: PERSON, Start: 0, End: 21
#  - Entity: itinerarium, Label: TITLE, Start: 22, End: 33
# ----------------------------------------
# Text: lucius apuleius madaurendo apologia
#  - Entity: lucius apuleius madaurendo, Label: PERSON, Start: 0, End: 26
#  - Entity: apologia, Label: TITLE, Start: 27, End: 35
# ----------------------------------------
# Text: thomas de aquinus officium de festum corpus christus
#  - Entity: thomas de aquinus, Label: PERSON, Start: 0, End: 17
#  - Entity: officium de festum corpus christus, Label: TITLE, Start: 18, End: 52
# ----------------------------------------
# Text: thomas de aquinus in threni hieremia
#  - Entity: thomas de aquinus, Label: PERSON, Start: 0, End: 17
#  - Entity: in threni hieremia, Label: TITLE, Start: 18, End: 36
# ----------------------------------------
# Text: thomas de aquinus principium biblicus
#  - Entity: thomas de aquinus, Label: PERSON, Start: 0, End: 17
#  - Entity: principium biblicus, Label: TITLE, Start: 18, End: 37
# ----------------------------------------
# Text: thomas de aquinus in ii sententia
#  - Entity: thomas de aquinus, Label: PERSON, Start: 0, End: 17
#  - Entity: in ii sententia, Label: TITLE, Start: 18, End: 33
# ----------------------------------------
# Text: flauior uopiscus syracusanus scriptor historia augustus
#  - Entity: flauior uopiscus syracusanus, Label: PERSON, Start: 0, End: 28
#  - Entity: scriptor historia augustus, Label: TITLE, Start: 29, End: 55
# ----------------------------------------
# Text: aelius  scriptor historia augustus
#  - Entity: scriptor historia augustus, Label: TITLE, Start: 8, End: 34
# ----------------------------------------
# Text: iulius capitolinus scriptor historia augustus
#  - Entity: iulius capitolinus, Label: PERSON, Start: 0, End: 18
#  - Entity: scriptor historia augustus, Label: TITLE, Start: 19, End: 45
# ----------------------------------------
# Text: uulcacius gallicanus scriptor historia augustus
#  - Entity: uulcacius gallicanus, Label: PERSON, Start: 0, End: 20
#  - Entity: scriptor historia augustus, Label: TITLE, Start: 21, End: 47
# ----------------------------------------
# Text: trebellus pollius scriptor historia augustus
#  - Entity: trebellus pollius, Label: PERSON, Start: 0, End: 17
#  - Entity: scriptor historia augustus, Label: TITLE, Start: 18, End: 44
# ----------------------------------------
# Text: aelius lamprider scriptor historia augustus
#  - Entity: aelius lamprider, Label: PERSON, Start: 0, End: 16
#  - Entity: scriptor historia augustus, Label: TITLE, Start: 17, End: 43
# ----------------------------------------
# Text: deasiderius eraasmus roterodao moria encomium
#  - Entity: deasiderius eraasmus roterodao, Label: PERSON, Start: 0, End: 30
#  - Entity: moria encomium, Label: TITLE, Start: 31, End: 45
# ----------------------------------------
# Text: alulphus tornacensis expositio uetus atque nosco testamentum
#  - Entity: alulphus tornacensis, Label: PERSON, Start: 0, End: 20
#  - Entity: expositio uetus atque nosco testamentum, Label: TITLE, Start: 21, End: 60
# ----------------------------------------
# Text: gennadus massiliensis de ecclesiasticus dogma
#  - Entity: gennadus massiliensis, Label: PERSON, Start: 0, End: 21
#  - Entity: de ecclesiasticus dogma, Label: TITLE, Start: 22, End: 45
# ----------------------------------------
# Text: felix i fragmentum
#  - Entity: felix i, Label: PERSON, Start: 0, End: 7
#  - Entity: fragmentum, Label: TITLE, Start: 8, End: 18
# ----------------------------------------
# Text: felix iii epistola et decretum
#  - Entity: felix iii, Label: PERSON, Start: 0, End: 9
#  - Entity: epistola et decretum, Label: TITLE, Start: 10, End: 30
# ----------------------------------------
# Text: felix iu epistola et decretum
#  - Entity: felix iu, Label: PERSON, Start: 0, End: 8
#  - Entity: epistola et decretum, Label: TITLE, Start: 9, End: 29
# ----------------------------------------
# Text: eutrope epistola ' de octo uitium '
#  - Entity: eutrope, Label: PERSON, Start: 0, End: 7
#  - Entity: epistola ' de octo uitium ', Label: TITLE, Start: 8, End: 35
# ----------------------------------------
# Text: decimus magnus ausone burdigalensus idyllium ( dubo . )
#  - Entity: decimus magnus ausone burdigalensus, Label: PERSON, Start: 0, End: 35
#  - Entity: idyllium ( dubo . ), Label: TITLE, Start: 36, End: 55
# ----------------------------------------
# Text: augustinus cantuariendo priuilegium abbatia cantuariendo
#  - Entity: augustinus cantuariendo, Label: PERSON, Start: 0, End: 23
#  - Entity: priuilegium abbatia cantuariendo, Label: TITLE, Start: 24, End: 56
# ----------------------------------------
# Text: ambrosius mediolanendo historia de excidium hierosolymitanus urbs anacephalaeosus ( dubo . )
#  - Entity: ambrosius mediolanendo, Label: PERSON, Start: 0, End: 22
#  - Entity: historia de excidium hierosolymitanus urbs anacephalaeosus ( dubo . ), Label: TITLE, Start: 23, End: 92
# ----------------------------------------
# Text: alphanus salernitanus charta renuntiatio
#  - Entity: alphanus salernitanus, Label: PERSON, Start: 0, End: 21
#  - Entity: charta renuntiatio, Label: TITLE, Start: 22, End: 40
# ----------------------------------------
# Text: ambrosius mediolanendo epistola de monachus energumenos ( dubo . )
#  - Entity: ambrosius mediolanendo, Label: PERSON, Start: 0, End: 22
#  - Entity: epistola de monachus energumenos ( dubo . ), Label: TITLE, Start: 23, End: 66
# ----------------------------------------
# Text: ambrosius mediolanendo de xlium mansio filius israel tractatus ( dubo . )
#  - Entity: ambrosius mediolanendo, Label: PERSON, Start: 0, End: 22
#  - Entity: de xlium mansio filius israel tractatus ( dubo . ), Label: TITLE, Start: 23, End: 73
# ----------------------------------------
# Text: ambrosius mediolanendo epistola de fides ad beatus hieronymus ( dubo . )
#  - Entity: ambrosius mediolanendo, Label: PERSON, Start: 0, End: 22
#  - Entity: epistola de fides ad beatus hieronymus ( dubo . ), Label: TITLE, Start: 23, End: 72
# ----------------------------------------
# Text: bernardus claraeuallensis hymnus
#  - Entity: bernardus claraeuallensis, Label: PERSON, Start: 0, End: 25
#  - Entity: hymnus, Label: TITLE, Start: 26, End: 32
# ----------------------------------------
# Text: baldus de ubalda nouus aesopus
#  - Entity: baldus de ubalda, Label: PERSON, Start: 0, End: 16
#  - Entity: nouus aesopus, Label: TITLE, Start: 17, End: 30
# ----------------------------------------

# %%
print(nlp.pipe_names)
# Out:
# ['senter', 'normer', 'tok2vec', 'tagger', 'morphologizer', 'trainable_lemmatizer', 'parser', 'lookup_lemmatizer', 'ner']

# %%
ner = nlp.get_pipe("ner")
ner.add_label("TITLE")
# Out:
# 1

# %%
import random
from spacy.training.example import Example

# Load your training data
doc_bin = DocBin().from_disk("train_data.spacy")
docs = list(doc_bin.get_docs(nlp.vocab))

# Disable other components in the pipeline during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]

# Start training
with nlp.disable_pipes(*other_pipes):
    optimizer = nlp.resume_training()
    for iteration in range(10):  # Adjust the number of iterations as needed
        random.shuffle(docs)
        losses = {}
        for doc in docs:
            example = Example.from_dict(doc, {"entities": [(ent.start_char, ent.end_char, ent.label_) for ent in doc.ents]})
            nlp.update([example], drop=0.5, losses=losses, sgd=optimizer)
        print(f"Iteration {iteration}: Losses {losses}")

nlp.to_disk("path_to_save_your_model")
# Out:
# Iteration 0: Losses {'ner': 3083.321723178891}
# Iteration 1: Losses {'ner': 1267.1095341879095}
# Iteration 2: Losses {'ner': 852.5200421897015}
# Iteration 3: Losses {'ner': 715.2959123770378}
# Iteration 4: Losses {'ner': 603.6691058241373}
# Iteration 5: Losses {'ner': 499.82435926955674}
# Iteration 6: Losses {'ner': 544.877397764566}
# Iteration 7: Losses {'ner': 406.6156816887558}
# Iteration 8: Losses {'ner': 447.4768492653248}
# Iteration 9: Losses {'ner': 399.5619176952475}

# %%
# Load the fine-tuned model
nlp = spacy.load("path_to_save_your_model")

# Test it on some text
doc = nlp("Virgil Aeneis")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Virgil PERSON
# Aeneis TITLE

# %%
# Load the fine-tuned model
nlp = spacy.load("path_to_save_your_model")

# Test it on some text
doc = nlp("Publius Statinius Statius Silva")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Publius Statinius Statius Silva PERSON

# %%
# Load the fine-tuned model
nlp = spacy.load("path_to_save_your_model")

# Test it on some text
doc = nlp("Silva")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Silva TITLE

# %%
# Load the fine-tuned model
nlp = spacy.load("path_to_save_your_model")

# Test it on some text
doc = nlp("Publius Papinius Statius Silvae")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Publius Papinius Statius PERSON
# Silvae TITLE
